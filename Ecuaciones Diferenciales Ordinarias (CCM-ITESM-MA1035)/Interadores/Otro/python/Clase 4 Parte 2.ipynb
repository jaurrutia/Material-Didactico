# %%
from math import * 
from numpy import *  
from scipy.integrate import * #from scipy import* antes sólo eso y luego lo integrate
from pylab import *
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm    #Color Managment
# %matplotlib inline

# %% [markdown]
# Vamos a definir una funcion potencial primeramente

# %%
def potencial(x,y,q,xq,yq):
    return q/sqrt((x-xq)**2+(y-yq)**2)

potencial(1,0,1,0,0) #Sí jala :3
# Out:
# 1.0

# %%
x=linspace(-1,1,5)
y=linspace(-2,1,5)
X,Y=meshgrid(x,y)  #Esto es hacer el producto cartesiano
print X             #Con esto se ven las diferencias de la X y Y
print Y
# Out:
# [[-1.  -0.5  0.   0.5  1. ]
#  [-1.  -0.5  0.   0.5  1. ]
#  [-1.  -0.5  0.   0.5  1. ]
#  [-1.  -0.5  0.   0.5  1. ]
#  [-1.  -0.5  0.   0.5  1. ]]
# [[-2.   -2.   -2.   -2.   -2.  ]
#  [-1.25 -1.25 -1.25 -1.25 -1.25]
#  [-0.5  -0.5  -0.5  -0.5  -0.5 ]
#  [ 0.25  0.25  0.25  0.25  0.25]
#  [ 1.    1.    1.    1.    1.  ]]

# %%
x=linspace(-1,1,20)
y=linspace(-1,1,20)
X,Y=meshgrid(x,y)
campo=quiver(X,Y)  #LE doy X,Y (los puntos de la maya)

# %%
fig=figure()    #Le digo que haga espacio para poner objetos
ax=Axes3D(fig)   #Aquí le digo que ponga mi figura en su espacio

# %%
ax.plot_surface(x,y,potencial) #Funciona como el .append() pero en su lugar le pongo una gráfica de una superficie
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-5e566f57eb10> in <module>()
# ----> 1 ax.plot_surface(x,y,potencial) #Funciona como el .append() pero en su lugar le pongo una gráfica de una superficie
#
# /Users/jonathanurrutia/anaconda/lib/python2.7/site-packages/mpl_toolkits/mplot3d/axes3d.pyc in plot_surface(self, X, Y, Z, *args, **kwargs)
#    1657
#    1658         self.add_collection(polyc)
# -> 1659         self.auto_scale_xyz(X, Y, Z, had_data)
#    1660
#    1661         return polyc
#
# /Users/jonathanurrutia/anaconda/lib/python2.7/site-packages/mpl_toolkits/mplot3d/axes3d.pyc in auto_scale_xyz(self, X, Y, Z, had_data)
#     455         self.xy_dataLim.update_from_data_xy(np.array([x, y]).T, not had_data)
#     456         if z is not None:
# --> 457             self.zz_dataLim.update_from_data_xy(np.array([z, z]).T, not had_data)
#     458
# ...
