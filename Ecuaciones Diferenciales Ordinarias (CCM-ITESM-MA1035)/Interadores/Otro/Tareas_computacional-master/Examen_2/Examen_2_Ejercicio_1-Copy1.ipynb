# %% [markdown]
# # Tarea Examen 1
# ### Ejercicio 1
#
# ## Jonathan Alexis Urrutia Anguiano 414011025

# %%
from pylab import *
from scipy.integrate import *
# %matplotlib inline

from JSAnimation import IPython_display
from matplotlib import animation

# %% [markdown]
# Supongamos uns sitema con un partícula moviéndose sobre una circunferencia de radio $R$. Entonces la velocidad es $\dot{\vec{r}} = r {\dot\theta}\hat{e}_\theta$ y el momento angular es
# $$
# \vec{L} = r\hat{e}_r \times m\dot{\vec{r}} = \hat{e}_z R^2m\dot{\theta},\\
# \Rightarrow \dot{\theta} = \frac{L}{mR^2},
# $$
# Por este resultado la energía del sistema es
# $$E=  \frac{p^2}{2m} = \frac{m^2r^2 {\dot\theta}^2}{2m} = \frac{L^2}{2mR^2},$$
# El sistema se perturba cada tiempo $\tau$ con un afuerza en la misma dirección, sentido y magnitud $\epsilon$. Esta fuerza cambia el momento lineal y el angular de forma instantenea. En el momento en el que la fuerza anterior actúa sobre la masa, el cambio en la cantidad de movimiento es $\Delta p = \epsilon \cos\theta$.
#
# Como $\Delta p = p_{i+1}- p_{i} \Rightarrow p_{i+1} = p_i + \Delta p$. Por lo que
# $$ p_{i+1} = p_i + \epsilon \cos\theta$$.
# Ya que $\theta = \theta_0 + \dot\theta t$ sabemos que $\Delta \theta = \dot\theta \Delta t$, pero $\Delta t = \tau$. Por otro lado, $\Delta \theta = \theta_i - \theta_{i+1}$, entonces
#
# \begin{align}
# \theta_{i+1} &= \theta_i + \Delta \theta\\
#             &= \theta_i + \dot{\theta} \Delta t\\
#             &=  \theta_i + \dot{\theta}\tau\\
#             &= \theta_i + \frac{L_{i+1}}{mR^2}\tau\\
# \end{align}

# %% [markdown]
# b) Con $\epsilon =0$ usar 200 condiciones iniciales tales que $p_0$ pertenezca a $[-\pi/2,\pi/2]$ y $\theta$ a $[0,2\pi]$. y encontrar las curvas en el plano ($\theta,p)$ que resultan de muchas iteraciones. Explicar

# %% [markdown]
# Hacemos un programa para que cree las condiciones iniciales aleatorias entre los intervalos pedidos.

# %%
def cond_ini():
    theta_0 = 2*pi*rand()
    p_0 = (.5-rand())*pi
    return array([theta_0,p_0])

# %% [markdown]
# Hacemos un programa para el mapeo:

# %%
def mapeo_per(theta_p, tau, epsilon):  #Mapeo cuando se perturba el sistema
    theta_0, p_0 = theta_p[0], theta_p[1]
    
    p_1 = p_0 + epsilon*cos(theta_0)
    theta_1 = theta_0 + p_1 * tau
    return array([theta_1,p_1])

# %% [markdown]
# Las ecuaciones de movimiento son muy sencillas, ya que la evolución en el tiempo de $\theta$ y p corresponden respectivamente a una evolución a omega constante y p constante, cuando la perturbación no está prendida, y a una evolución descrita por las expresiones de a) cuando prendemos la perturbación.

# %% [markdown]
# Resolvemos ahora la evolución del sistema para 200 condiciones iniciales aleatorias.

# %%
fig = figure(figsize=(10,10))
ax = fig.add_subplot(111)
title(r"$\theta$ vs. $p$ ",fontsize = 30), xlabel(r'$\theta$',fontsize = 20), ylabel(r'$p$',fontsize = 20) 
grid(True)

tau = 2
epsilon =0
t = arange(0,200,.1)

for i in xrange(200):
    sol = zeros([len(t),2])
    sol[0] = cond_ini()
    
    for j in xrange(len(t)-1):
        if t[j] %(tau) == 0:
            sol[j+1] = mapeo_per(sol[j],tau,epsilon)
        else:
            sol[j+1] = mapeo_per(sol[j],tau,0)
        sol[j+1][0] = sol[j+1][0] % (2*pi)
    plot(sol[:,0],sol[:,1],'.',markersize = 1)
show()

# %% [markdown]
# Para que los puntos sean fijos, es necesario que $\theta_{i+1} = \theta_i$ y que $p_{i+1} = p_i$. De las ecuaciones anteriores, para que esto sea cierto, es necesario que se cumplea $\cos\theta = 0$, suponiendo que $\epsilon$ no es nulo. Entonces, los puntos estacionarios estáne en
# $$\theta = \frac{\pi}{2}, \frac{3 \pi}{2}$$

# %%
epsilon = array([0.01,0.05,0.1,0.2,0.3,0.4,0.7, 1.1])
tau = 1
t = arange(0,200,.1)

fig, ax = plt.subplots(figsize=(20, 40))
for i in xrange(len(epsilon)):
    for j in xrange(200):
        sol = zeros([len(t),2])
        sol[0] = cond_ini()
        
        for k in xrange(len(t)-1):
            if abs(t[k] %(tau)) < 1e-4:
                sol[k+1] = mapeo_per(sol[k],tau,epsilon[i])
            else:
                sol[k+1] = mapeo_per(sol[k],tau,epsilon[i])
            sol[k+1][0] = sol[k+1][0] % (2*pi)
        subplot(4,2,i+1)
        title(r"$\theta$ vs. $p$ con $\epsilon = %s$" %(str(epsilon[i])),fontsize = 30)
        xlabel(r'$\theta$',fontsize = 20), ylabel(r'$p$',fontsize = 20), grid(True)
        xlim(0,2*pi)
        plot(sol[:,0],sol[:,1],'.',markersize = .5)
ax.legend(bbox_to_anchor=(1.05, 1.0), loc=2, borderaxespad=0.)
show()
# Out:
# C:\Users\Jonathan\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:519: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
figura = figure() #Crea la figura
ejes = axes(xlim=(0,pi*2),ylim=(-3,3))


trayectoria, = ejes.plot([],[],lw=2)
punto, = ejes.plot([],[],'o')

def init():
    trayectoria.set_data([],[])
    punto.set_data([],[])
    return trayectoria, punto,  #Inicializa variables

def el_movimiento(i):
    y,v = sol[:,0],sol[:,1]
    trayectoria.set_data(y[:i+1],v[:i+1])
    punto.set_data(y[i],v[i])
    tache =ejes.plot([0],[0],'x')  #El tache siempre aparece porque tu funcion init no lo contempla
    return trayectoria,punto
    
animation.FuncAnimation(figura,el_movimiento, init_func = init , frames =len(sol[:,0])) # los argumentos son el entorno, lo que va a animar la función borron y cuenta nueva
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-d87826efedfa> in <module>()
#      18     return trayectoria,punto
#      19
# ---> 20 animation.FuncAnimation(figura,el_movimiento, init_func = init , frames =len(sol[:,0])) # los argumentos son el entorno, lo que va a animar la función borron y cuenta nueva
#
# C:\Users\Jonathan\Anaconda2\lib\site-packages\IPython\core\displayhook.pyc in __call__(self, result)
#     244             self.start_displayhook()
#     245             self.write_output_prompt()
# --> 246             format_dict, md_dict = self.compute_format_data(result)
#     247             self.update_user_ns(result)
#     248             self.fill_exec_result(result)
#
# C:\Users\Jonathan\Anaconda2\lib\site-packages\IPython\core\displayhook.pyc in compute_format_data(self, result)
#     150
#     151         """
# --> 152         return self.shell.display_formatter.format(result)
#     153
#     154     def write_format_data(self, format_dict, md_dict=None):
#
# C:\Users\Jonathan\Anaconda2\lib\site-packages\IPython\core\formatters.pyc in format(self, obj, include, exclude)
#     175             md = None
#     176             try:
# --> 177                 data = formatter(obj)
#     178             except:
#     179                 # FIXME: log the exception
#
# <decorator-gen-9> in __call__(self, obj)
#
# C:\Users\Jonathan\Anaconda2\lib\site-packages\IPython\core\formatters.pyc in catch_format_error(method, self, *args, **kwargs)
#     220     """show traceback on failed format call"""
#     221     try:
# --> 222         r = method(self, *args, **kwargs)
#     223     except NotImplementedError:
#     224         # don't warn on NotImplementedErrors
#
# C:\Users\Jonathan\Anaconda2\lib\site-packages\IPython\core\formatters.pyc in __call__(self, obj)
#     341             method = _safe_get_formatter_method(obj, self.print_method)
#     342             if method is not None:
# --> 343                 return method()
#     344             return None
#     345         else:
#
# C:\Users\Jonathan\Documents\GitHub\Fis_Computacional\Tareas_computacional\Examen_2\JSAnimation\IPython_display.pyc in anim_to_html(anim, fps, embed_frames, default_mode)
#      74             anim.save(f.name,  writer=HTMLWriter(fps=fps,
#      75                                                  embed_frames=embed_frames,
# ---> 76                                                  default_mode=default_mode))
#      77             html = open(f.name).read()
#      78
#
# C:\Users\Jonathan\Anaconda2\lib\site-packages\matplotlib\animation.pyc in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs)
#     808                     # TODO: Need to see if turning off blit is really necessary
#     809                     anim._draw_next_frame(d, blit=False)
# --> 810                 writer.grab_frame(**savefig_kwargs)
#     811
#     812         # Reconnect signal for first draw if necessary
#
# C:\Users\Jonathan\Documents\GitHub\Fis_Computacional\Tareas_computacional\Examen_2\JSAnimation\html_writer.pyc in grab_frame(self, **savefig_kwargs)
#     287             f = InMemory()
#     288             self.fig.savefig(f, format=self.frame_format,
# --> 289                              dpi=self.dpi, **savefig_kwargs)
#     290             f.seek(0)
#     291             self._saved_frames.append(b64encode(f.read()).decode('ascii'))
#
# C:\Users\Jonathan\Anaconda2\lib\site-packages\matplotlib\figure.pyc in savefig(self, *args, **kwargs)
#    1563             self.set_frameon(frameon)
#    1564
# -> 1565         self.canvas.print_figure(*args, **kwargs)
#    1566
#    1567         if frameon:
#
# C:\Users\Jonathan\Anaconda2\lib\site-packages\matplotlib\backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2230                 orientation=orientation,
#    2231                 bbox_inches_restore=_bbox_inches_restore,
# -> 2232                 **kwargs)
#    2233         finally:
#    2234             if bbox_inches and restore_bbox:
#
# C:\Users\Jonathan\Anaconda2\lib\site-packages\matplotlib\backends\backend_agg.pyc in print_png(self, filename_or_obj, *args, **kwargs)
#     525
#     526     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 527         FigureCanvasAgg.draw(self)
#     528         renderer = self.get_renderer()
#     529         original_dpi = renderer.dpi
#
# C:\Users\Jonathan\Anaconda2\lib\site-packages\matplotlib\backends\backend_agg.pyc in draw(self)
#     472
#     473         try:
# --> 474             self.figure.draw(self.renderer)
#     475         finally:
#     476             RendererAgg.lock.release()
#
# C:\Users\Jonathan\Anaconda2\lib\site-packages\matplotlib\artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# C:\Users\Jonathan\Anaconda2\lib\site-packages\matplotlib\figure.pyc in draw(self, renderer)
#    1157         dsu.sort(key=itemgetter(0))
#    1158         for zorder, a, func, args in dsu:
# -> 1159             func(*args)
#    1160
#    1161         renderer.close_group('figure')
#
# C:\Users\Jonathan\Anaconda2\lib\site-packages\matplotlib\artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# C:\Users\Jonathan\Anaconda2\lib\site-packages\matplotlib\axes\_base.pyc in draw(self, renderer, inframe)
#    2322
#    2323         for zorder, a in dsu:
# -> 2324             a.draw(renderer)
#    2325
#    2326         renderer.close_group('axes')
#
# C:\Users\Jonathan\Anaconda2\lib\site-packages\matplotlib\artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# C:\Users\Jonathan\Anaconda2\lib\site-packages\matplotlib\lines.pyc in draw(self, renderer)
#     779
#     780             marker = self._marker
# --> 781             tpath, affine = transf_path.get_transformed_points_and_affine()
#     782             if len(tpath.vertices):
#     783                 # subsample the markers if markevery is not None
#
# C:\Users\Jonathan\Anaconda2\lib\site-packages\matplotlib\transforms.pyc in get_transformed_points_and_affine(self)
#    2701         """
#    2702         self._revalidate()
# -> 2703         return self._transformed_points, self.get_affine()
#    2704
#    2705     def get_transformed_path_and_affine(self):
#
# C:\Users\Jonathan\Anaconda2\lib\site-packages\matplotlib\transforms.pyc in get_affine(self)
#    2720
#    2721     def get_affine(self):
# -> 2722         return self._transform.get_affine()
#    2723
#    2724
#
# C:\Users\Jonathan\Anaconda2\lib\site-packages\matplotlib\transforms.pyc in get_affine(self)
#    2372             return self._b.get_affine()
#    2373         else:
# -> 2374             return Affine2D(np.dot(self._b.get_affine().get_matrix(),
#    2375                                 self._a.get_affine().get_matrix()))
#    2376     get_affine.__doc__ = Transform.get_affine.__doc__
#
# C:\Users\Jonathan\Anaconda2\lib\site-packages\matplotlib\transforms.pyc in get_affine(self)
#    2373         else:
#    2374             return Affine2D(np.dot(self._b.get_affine().get_matrix(),
# -> 2375                                 self._a.get_affine().get_matrix()))
#    2376     get_affine.__doc__ = Transform.get_affine.__doc__
#    2377
#
# C:\Users\Jonathan\Anaconda2\lib\site-packages\matplotlib\transforms.pyc in __init__(self, matrix, **kwargs)
#    1794         If *matrix* is None, initialize with the identity transform.
#    1795         """
# -> 1796         Affine2DBase.__init__(self, **kwargs)
#    1797         if matrix is None:
#    1798             matrix = np.identity(3)
#
# C:\Users\Jonathan\Anaconda2\lib\site-packages\matplotlib\transforms.pyc in __init__(self, *args, **kwargs)
#    1639
#    1640     def __init__(self, *args, **kwargs):
# -> 1641         Transform.__init__(self, *args, **kwargs)
#    1642         self._inverted = None
#    1643
#
# C:\Users\Jonathan\Anaconda2\lib\site-packages\matplotlib\transforms.pyc in __init__(self, shorthand_name)
#     101         # computed for the first time.
#     102         self._invalid = 1
# --> 103         self._shorthand_name = shorthand_name or ''
#     104
#     105     if DEBUG:
#
# KeyboardInterrupt:
